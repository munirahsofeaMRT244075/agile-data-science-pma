# %%
# !pip install pytest -q
# !git clone https://github.com/munirahsofeaMRT244075/agile-data-science-pma.git
# %cd agile-data-science-pma
# !pytest tests/ -v
# Out:
# Cloning into 'agile-data-science-pma'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 34 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 489.02 KiB | 7.89 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/agile-data-science-pma
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/agile-data-science-pma
# plugins: anyio-4.14.0, typeguard-4.5.2, langsmith-0.9.1
# collected 3 items
#
# tests/test_validation.py::test_no_duplicate_rows PASSED                  [ 33%]
# tests/test_validation.py::test_total_charges_no_blanks FAILED            [ 66%]
# tests/test_validation.py::test_churn_values_valid PASSED                 [100%]
#
# ...

# %%
# open the file that just worked, straight from your cloned repo
with open("tests/test_validation.py") as f:
    print(f.read())
# Out:
# import pandas as pd
#
# DATA_URL = "https://raw.githubusercontent.com/munirahsofeaMRT244075/agile-data-science-pma/refs/heads/main/data./telco.csv"
#
# def load_data():
#     return pd.read_csv(DATA_URL)
#
# def test_no_duplicate_rows():
#     df = load_data()
#     assert df.duplicated().sum() == 0, "Dataset contains duplicate rows"
#
# def test_total_charges_no_blanks():
#     df = load_data()
#     blanks = (df['TotalCharges'].astype(str).str.strip() == '').sum()
#     assert blanks == 0, f"TotalCharges has {blanks} blank values"
#
# def test_churn_values_valid():
#     df = load_data()
#     valid_values = {'Yes', 'No'}
#     assert set(df['Churn'].unique()).issubset(valid_values), "Churn column has unexpected values"
